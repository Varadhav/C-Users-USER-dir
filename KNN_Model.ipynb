# %%
import pandas as pd
tel_data = pd.read_csv(r'C:\Users\USER\Python Files\telescope_data.csv')

# %%
tel_data.head()
# Out:
#    Unnamed: 0   fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  \
# 0           0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110
# 1           1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238
# 2           2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580
# 3           3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633
# 4           4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525
#
#    fM3Trans   fAlpha     fDist class
# 0   -8.2027  40.0920   81.8828     g
# 1   -9.9574   6.3609  205.2610     g
# 2  -45.2160  76.9600  256.7880     g
# 3   -7.1513  10.4490  116.7370     g
# 4   21.8393   4.6480  356.4620     g

# %%
tel_data.columns = [cols.lower() for cols in tel_data.columns]

# %%
tel_data.head()
# Out:
#    unnamed: 0   flength    fwidth   fsize   fconc  fconc1     fasym  fm3long  \
# 0           0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110
# 1           1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238
# 2           2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580
# 3           3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633
# 4           4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525
#
#    fm3trans   falpha     fdist class
# 0   -8.2027  40.0920   81.8828     g
# 1   -9.9574   6.3609  205.2610     g
# 2  -45.2160  76.9600  256.7880     g
# 3   -7.1513  10.4490  116.7370     g
# 4   21.8393   4.6480  356.4620     g

# %%
tel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19020 entries, 0 to 19019
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   unnamed: 0  19020 non-null  int64
#  1   flength     19020 non-null  float64
#  2   fwidth      19020 non-null  float64
#  3   fsize       19020 non-null  float64
#  4   fconc       19020 non-null  float64
#  5   fconc1      19020 non-null  float64
#  6   fasym       19020 non-null  float64
#  7   fm3long     19020 non-null  float64
#  8   fm3trans    19020 non-null  float64
#  9   falpha      19020 non-null  float64
#  10  fdist       19020 non-null  float64
#  11  class       19020 non-null  object
# dtypes: float64(10), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
tel_data.describe()
# Out:
#          unnamed: 0       flength        fwidth         fsize         fconc  \
# count  19020.000000  19020.000000  19020.000000  19020.000000  19020.000000
# mean    9509.500000     53.250154     22.180966      2.825017      0.380327
# std     5490.745396     42.364855     18.346056      0.472599      0.182813
# min        0.000000      4.283500      0.000000      1.941300      0.013100
# 25%     4754.750000     24.336000     11.863800      2.477100      0.235800
# 50%     9509.500000     37.147700     17.139900      2.739600      0.354150
# 75%    14264.250000     70.122175     24.739475      3.101600      0.503700
# max    19019.000000    334.177000    256.382000      5.323300      0.893000
#
#              fconc1         fasym       fm3long      fm3trans        falpha  \
# count  19020.000000  19020.000000  19020.000000  19020.000000  19020.000000
# mean       0.214657     -4.331745     10.545545      0.249726     27.645707
# std        0.110511     59.206062     51.000118     20.827439     26.103621
# min        0.000300   -457.916100   -331.780000   -205.894700      0.000000
# 25%        0.128475    -20.586550    -12.842775    -10.849375      5.547925
# 50%        0.196500      4.013050     15.314100      0.666200     17.679500
# 75%        0.285225     24.063700     35.837800     10.946425     45.883550
# max        0.675200    575.240700    238.321000    179.851000     90.000000
#
#               fdist
# count  19020.000000
# mean     193.818026
# std       74.731787
# min        1.282600
# 25%      142.492250
# 50%      191.851450
# 75%      240.563825
# max      495.561000

# %%
import matplot.pyplot as plt
for label in (tel_data.comumn):
    plt.hist(tel_data[tel_data['class']=='g][label], color='yellow', label= 'gamma', alpha =0.5, destiny=True)
    plt.hist(tel_data[tel_data['class']=='h][label], color='orange', label= 'hadron', alpha =0.5, destiny=True)
    plt.title(label)
    plt.ylabel ("probability")
    plt.ylabel (label)
    plt.legend()
    plt.show
# Out:
#   Cell In[23], line 3
#     plt.hist(tel_data[tel_data[class ']=='g][label], color='yellow', label= 'gamma', alpha =0.5, destiny=True)
#                                                                                                              ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
import matplot.pyplot as plt
for label in (tel_data.comumn):
    plt.hist(tel_data[tel_data['class']=='g][label], color='yellow', label= 'gamma', alpha =0.5, destiny=True)
    plt.hist(tel_data[tel_data['class']=='h][label], color='orange', label= 'hadron', alpha =0.5, destiny=True)
    plt.title(label)
    plt.ylabel ("probability")
    plt.ylabel (label)
    plt.legend()
    plt.show
# Out:
#   Cell In[24], line 3
#     plt.hist(tel_data[tel_data['class']=='g][label], color='yellow', label= 'gamma', alpha =0.5, destiny=True)
#                                                                                   ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
import matplotlib.pyplot as plt

for label in tel_data.columns:
    plt.hist(tel_data[tel_data['class'] == 'g'][label], color='yellow', label='gamma', alpha=0.5, density=True)
    plt.hist(tel_data[tel_data['class'] == 'h'][label], color='orange', label='hadron', alpha=0.5, density=True)
    
    plt.title(label)
    plt.ylabel("Probability")
    plt.xlabel(label)
    plt.legend()
    plt.show()

# %%
from sklearn.model_selection import train_test_split
ds_train, ds_test = train_test_split(tel_data, test_size=0.2)

# %%
print(len(ds_train))
print(len(ds_test))
# Out:
# 15216
# 3804

# %%
print(len(ds_train[ds_train['class'] == 'g']))
print(len(ds_train[ds_train['class'] == 'h']))
# Out:
# 9870
# 5346

# %%
from imblearn.over_sampling import RandomOverSampler
r_sam = RandomOverSampler()
in_ds_train = ds_train.drop(columns=['class'])
out_ds_train = ds_train['class']

# %%
print (in_ds_train)
# Out:
#        unnamed: 0   flength   fwidth   fsize   fconc  fconc1     fasym  \
# 475           475   27.8936  23.3166  2.8698  0.3549  0.1964   11.4203
# 15334       15334   69.0328  17.7090  2.7316  0.3588  0.2149   48.7830
# 10729       10729   82.6460  38.0362  3.6750  0.1957  0.1024   49.1207
# 7092         7092   54.0250  17.8851  3.0241  0.2753  0.1670   21.5915
# 14805       14805   34.1721   8.7107  2.5729  0.4091  0.2152  -26.7900
# ...           ...       ...      ...     ...     ...     ...       ...
# 433           433   38.0902  23.3226  3.2331  0.2619  0.1535   30.0035
# 13757       13757   17.7926  11.6190  2.5139  0.6003  0.4364   -0.0457
# 13944       13944  107.7187  85.7887  3.3068  0.1577  0.0891 -107.4243
# 657           657   12.6471  11.7783  2.1569  0.7108  0.3589  -15.1635
# 13846       13846   89.8938  33.6844  3.4545  0.1496  0.0830 -101.8506
#
#        fm3long  fm3trans   falpha     fdist
# 475    17.6953  -15.0672  82.8799   83.9734
# 15334  68.6052   12.1395  47.3230  267.7166
# 10729  98.2205  -24.3188  23.5114  269.8120
# 7092   43.6579    6.1489   2.4990  266.9680
# 14805   3.9281   -3.8166  69.0700  180.5390
# ...        ...       ...      ...       ...
# 433    27.8475  -13.6954  25.6015   78.4666
# 13757  -8.0966   11.1834  40.8770  221.1050
# 13944 -44.4384   30.4157  65.7382  282.7957
# 657     4.7420   11.4747  31.7760  172.7250
# 13846  62.9762   22.2197   5.1881  250.6162
#
# [15216 rows x 11 columns]

# %%
print (out_ds_train)
# Out:
# 475      g
# 15334    h
# 10729    g
# 7092     g
# 14805    h
#         ..
# 433      g
# 13757    h
# 13944    h
# 657      g
# 13846    h
# Name: class, Length: 15216, dtype: object

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
in_ds_train = scaler.fit_transform(in_ds_train)
print(in_ds_train)
# Out:
# [[-1.644303   -0.59931931  0.06258487 ... -0.73506848  2.1130595
#   -1.46818484]
#  [ 1.06416118  0.36934846 -0.24447788 ...  0.57043709  0.75192293
#    0.99206803]
#  [ 0.22477242  0.68988625  0.86860542 ... -1.17900381 -0.15959746
#    1.02012465]
#  ...
#  [ 0.81079519  1.28025058  3.48345204 ...  1.44741522  1.45686633
#    1.19397155]
#  [-1.61112846 -0.95831495 -0.56923304 ...  0.53853685  0.15677571
#   -0.27983404]
#  [ 0.79293197  0.86054368  0.63030817 ...  1.05413255 -0.86102289
#    0.76310005]]

# %%
in_ds_train, out_ds_train = r_sam.fit_resample(in_ds_train, out_ds_train)
print(len(out_ds_train))
print(sum(out_ds_train == 'g'))
print(sum(out_ds_train == 'h'))
# Out:
# 19740
# 9870
# 9870

# %%
in_ds_test = ds_test.drop(columns=['class'])
out_ds_test = ds_test['class']
in_ds_test = scaler.fit_transform(in_ds_test)

# %%
print(len(in_ds_test))
# Out:
# 3804

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors=1)
knn_model.fit(in_ds_train, out_ds_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
out_pred = knn_model.predict(in_ds_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_info = accuracy_score(out_ds_test, out_pred)
accuracy_info
# Out:
# 0.9718717139852786

# %%
from sklearn.metrics import classification_report
print(classification_report(out_ds_test, out_pred))
# Out:
#               precision    recall  f1-score   support
#
#            g       0.97      0.99      0.98      2462
#            h       0.98      0.94      0.96      1342
#
#     accuracy                           0.97      3804
#    macro avg       0.97      0.96      0.97      3804
# weighted avg       0.97      0.97      0.97      3804
